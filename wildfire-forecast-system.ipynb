# %%
import datetime as dt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestRegressor

# %%
df=pd.read_csv("/kaggle/input/firedataset/fire_archive.csv")

# %%
df.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  -11.8070   142.0583       313.0   1.0    1.0  2019-08-01        56
# 1  -11.7924   142.0850       319.3   1.0    1.0  2019-08-01        56
# 2  -12.8398   132.8744       311.6   3.1    1.7  2019-08-01        57
# 3  -14.4306   143.3035       310.1   1.1    1.1  2019-08-01        57
# 4  -12.4953   131.4897       310.3   4.0    1.9  2019-08-01        57
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS          48      6.3       297.3   6.6        D     0
# 1     Terra      MODIS          71      6.3       297.3  11.3        D     0
# 2     Terra      MODIS          42      6.3       298.7  23.1        D     0
# 3     Terra      MODIS          33      6.3       296.1   6.5        D     0
# 4     Terra      MODIS          36      6.3       298.8  27.6        D     0

# %%
df.shape
# Out:
# (36011, 15)

# %%
df.isnull().sum()
# Out:
# latitude      0
# longitude     0
# brightness    0
# scan          0
# track         0
# acq_date      0
# acq_time      0
# satellite     0
# instrument    0
# confidence    0
# version       0
# bright_t31    0
# frp           0
# daynight      0
# type          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36011 entries, 0 to 36010
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    36011 non-null  float64
#  1   longitude   36011 non-null  float64
#  2   brightness  36011 non-null  float64
#  3   scan        36011 non-null  float64
#  4   track       36011 non-null  float64
#  5   acq_date    36011 non-null  object
#  6   acq_time    36011 non-null  int64
#  7   satellite   36011 non-null  object
#  8   instrument  36011 non-null  object
#  9   confidence  36011 non-null  int64
#  10  version     36011 non-null  float64
#  11  bright_t31  36011 non-null  float64
#  12  frp         36011 non-null  float64
#  13  daynight    36011 non-null  object
#  14  type        36011 non-null  int64
# dtypes: float64(8), int64(3), object(4)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#            latitude     longitude    brightness          scan         track  \
# count  36011.000000  36011.000000  36011.000000  36011.000000  36011.000000
# mean     -19.100962    138.931446    328.750696      1.620905      1.215281
# std        7.265777      9.261400     18.992808      0.813764      0.247852
# min      -42.762800    114.104300    300.000000      1.000000      1.000000
# 25%      -26.370250    131.072250    316.500000      1.100000      1.000000
# 50%      -15.706500    136.738500    326.400000      1.300000      1.100000
# 75%      -13.343600    147.477500    336.700000      1.900000      1.300000
# max      -10.072600    153.490400    504.400000      4.800000      2.000000
#
#            acq_time    confidence       version    bright_t31           frp  \
# count  36011.000000  36011.000000  3.601100e+04  36011.000000  36011.000000
# mean     600.025798     67.551387  6.300000e+00    301.339138     51.132176
# std      548.369111     23.179946  3.728625e-12      9.724462     92.280112
# min        0.000000      0.000000  6.300000e+00    267.000000      0.000000
# 25%      205.000000     52.000000  6.300000e+00    293.600000     13.800000
# 50%      424.000000     70.000000  6.300000e+00    302.400000     25.800000
# 75%      600.000000     86.000000  6.300000e+00    308.600000     52.800000
# max     2359.000000    100.000000  6.300000e+00    400.100000   3679.500000
#
#                type
# count  36011.000000
# mean       0.019439
# std        0.198326
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000

# %%
df.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  -11.8070   142.0583       313.0   1.0    1.0  2019-08-01        56
# 1  -11.7924   142.0850       319.3   1.0    1.0  2019-08-01        56
# 2  -12.8398   132.8744       311.6   3.1    1.7  2019-08-01        57
# 3  -14.4306   143.3035       310.1   1.1    1.1  2019-08-01        57
# 4  -12.4953   131.4897       310.3   4.0    1.9  2019-08-01        57
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS          48      6.3       297.3   6.6        D     0
# 1     Terra      MODIS          71      6.3       297.3  11.3        D     0
# 2     Terra      MODIS          42      6.3       298.7  23.1        D     0
# 3     Terra      MODIS          33      6.3       296.1   6.5        D     0
# 4     Terra      MODIS          36      6.3       298.8  27.6        D     0

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Univariate Visualizations of Confidence')

# Histogram
sns.histplot(df['confidence'], bins=5, kde=False, ax=axes[0])
axes[0].set_title('Histogram')
axes[0].set_xlabel('Confidence')
axes[0].set_ylabel('Frequency')

# Box Plot
sns.boxplot(y=df['confidence'], ax=axes[1])
axes[1].set_title('Box Plot')
axes[1].set_ylabel('Confidence')

# Kernel Density Plot
sns.kdeplot(df['confidence'], bw_adjust=0.5, ax=axes[2])
axes[2].set_title('Kernel Density Plot')
axes[2].set_xlabel('Confidence')
axes[2].set_ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
numerical_features = ['brightness', 'frp', 'bright_t31', 'scan', 'track']
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Confidence vs. Numerical Features')
axes = axes.flatten()

for i, feature in enumerate(numerical_features):
    sns.scatterplot(x=df[feature], y=df['confidence'], ax=axes[i])
    axes[i].set_title(f'vs. {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Confidence')

# Remove empty subplot (if any)
if len(numerical_features) < len(axes):
    for j in range(len(numerical_features), len(axes)):
        fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 8))
corr = df[['confidence', 'brightness', 'frp', 'bright_t31', 'scan', 'track', 'latitude', 'longitude']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature


plt.figure(figsize=(15, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
scatter = ax.scatter(df['longitude'], df['latitude'], c=df['confidence'], s=100, cmap='viridis', transform=ccrs.PlateCarree())
plt.colorbar(scatter, label='Confidence')
ax.set_title('Confidence on Map')
ax.set_extent([130, 145, -15, -10], crs=ccrs.PlateCarree())  # Zoom to the region
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.scatterplot(x=df['acq_time'], y=df['confidence'])
plt.title('Confidence vs. Acquisition Time')
plt.xlabel('Acquisition Time (minutes)')
plt.ylabel('Confidence')
plt.show()

# %%
sns.pairplot(df[['confidence', 'brightness', 'frp', 'bright_t31', 'scan', 'track']])
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(df['brightness'], df['frp'], df['confidence'], c=df['confidence'], cmap='viridis')
ax.set_xlabel('Brightness')
ax.set_ylabel('FRP')
ax.set_zlabel('Confidence')
plt.title('3D Scatter: Confidence vs. Brightness vs. FRP')
fig.colorbar(scatter, label='Confidence')
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.scatter(df['longitude'], df['latitude'], s=df['confidence']*10, c=df['brightness'], cmap='plasma', alpha=0.6)
plt.colorbar(label='Brightness')
plt.title('Bubble Plot: Confidence (size) and Brightness (color)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.regplot(x=df['brightness'], y=df['confidence'])
plt.title('Regression Plot: Confidence vs. Brightness')
plt.xlabel('Brightness')
plt.ylabel('Confidence')
plt.show()

# %%
df.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  -11.8070   142.0583       313.0   1.0    1.0  2019-08-01        56
# 1  -11.7924   142.0850       319.3   1.0    1.0  2019-08-01        56
# 2  -12.8398   132.8744       311.6   3.1    1.7  2019-08-01        57
# 3  -14.4306   143.3035       310.1   1.1    1.1  2019-08-01        57
# 4  -12.4953   131.4897       310.3   4.0    1.9  2019-08-01        57
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS          48      6.3       297.3   6.6        D     0
# 1     Terra      MODIS          71      6.3       297.3  11.3        D     0
# 2     Terra      MODIS          42      6.3       298.7  23.1        D     0
# 3     Terra      MODIS          33      6.3       296.1   6.5        D     0
# 4     Terra      MODIS          36      6.3       298.8  27.6        D     0

# %%
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import mean_squared_error, r2_score

features = ['latitude', 'longitude', 'brightness', 'scan', 'track', 'acq_time', 'bright_t31', 'frp']
X = df[features]
y = df['confidence']
baseline_model = CatBoostRegressor(random_seed=42, verbose=0)
baseline_model.fit(X, y)

# %%
y_pred_baseline = baseline_model.predict(X)
baseline_rmse = np.sqrt(mean_squared_error(y, y_pred_baseline))
baseline_r2 = r2_score(y, y_pred_baseline)
print("Baseline CatBoost Model:")
print(f"RMSE: {baseline_rmse:.2f}")
print(f"R²: {baseline_r2:.2f}")
# Out:
# Baseline CatBoost Model:
# RMSE: 11.66
# R²: 0.75

# %%
param_grid = {
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'iterations': [100, 200],
    'l2_leaf_reg': [1, 3, 5]
}
model = CatBoostRegressor(random_seed=42, verbose=100)

cv = KFold(n_splits=3, shuffle=True, random_state=42)
grid_search = GridSearchCV(estimator=model,param_grid=param_grid,cv=cv,scoring='neg_mean_squared_error',n_jobs=-1)
grid_search.fit(X, y)
# Out:
# 0:	learn: 23.0808702	total: 56.6ms	remaining: 5.6s
# 0:	learn: 23.1296154	total: 58.7ms	remaining: 5.81s
# 0:	learn: 23.0164285	total: 63.2ms	remaining: 6.26s
# 0:	learn: 22.6769528	total: 67.8ms	remaining: 6.71s
# 99:	learn: 17.4476592	total: 1.29s	remaining: 0us
# 99:	learn: 17.4575518	total: 1.32s	remaining: 0us
# 0:	learn: 22.7149670	total: 21.2ms	remaining: 2.1s
# 99:	learn: 14.6072042	total: 1.32s	remaining: 0us
# 0:	learn: 22.6062251	total: 15.5ms	remaining: 1.53s
# 99:	learn: 17.3841313	total: 1.54s	remaining: 0us
# 0:	learn: 22.1858550	total: 12.5ms	remaining: 1.24s
# 0:	learn: 22.2105772	total: 30ms	remaining: 2.96s
# 99:	learn: 14.5161373	total: 983ms	remaining: 0us
# 0:	learn: 22.1073052	total: 15.2ms	remaining: 1.5s
# 99:	learn: 14.0554922	total: 896ms	remaining: 0us
# 99:	learn: 14.5166320	total: 1.42s	remaining: 0us
# 0:	learn: 23.0810185	total: 9ms	remaining: 891ms
# 0:	learn: 23.1297272	total: 31.9ms	remaining: 3.15s
# 99:	learn: 13.9746531	total: 1.14s	remaining: 0us
# 0:	learn: 23.0165230	total: 24.9ms	remaining: 2.47s
# 99:	learn: 13.9815956	total: 969ms	remaining: 0us
# 0:	learn: 22.6776776	total: 16ms	remaining: 1.58s
# 99:	learn: 17.4592803	total: 1.17s	remaining: 0us
# 0:	learn: 22.7155135	total: 21.1ms	remaining: 2.09s
# 99:	learn: 17.4614411	total: 1.59s	remaining: 0us
# 99:	learn: 17.3797372	total: 1.45s	remaining: 0us
# 0:	learn: 22.6066869	total: 33.6ms	remaining: 3.33s
# 0:	learn: 22.1872610	total: 13.8ms	remaining: 1.36s
# 99:	learn: 14.6220357	total: 1.01s	remaining: 0us
# 0:	learn: 22.2116364	total: 5.92ms	remaining: 586ms
# 99:	learn: 14.5275016	total: 857ms	remaining: 0us
# 0:	learn: 22.1082001	total: 13.4ms	remaining: 1.32s
# 99:	learn: 14.5301469	total: 1.36s	remaining: 0us
# 0:	learn: 23.0811615	total: 28.2ms	remaining: 2.8s
# 99:	learn: 14.0814385	total: 1.54s	remaining: 0us
# 99:	learn: 13.9846513	total: 1.38s	remaining: 0us
# 0:	learn: 23.1298384	total: 18.2ms	remaining: 1.8s
# 0:	learn: 23.0166169	total: 35.1ms	remaining: 3.48s
# 99:	learn: 13.9973928	total: 1.32s	remaining: 0us
# 0:	learn: 22.6783764	total: 18.5ms	remaining: 1.83s
# 99:	learn: 17.4635973	total: 1.02s	remaining: 0us
# 0:	learn: 22.7160570	total: 25.8ms	remaining: 2.55s
# 99:	learn: 17.4631283	total: 1.22s	remaining: 0us
# 0:	learn: 22.6071457	total: 16.8ms	remaining: 1.66s
# 99:	learn: 17.3787714	total: 1.33s	remaining: 0us
# 0:	learn: 22.1886162	total: 10.8ms	remaining: 1.07s
# 99:	learn: 14.6143658	total: 1.31s	remaining: 0us
# 0:	learn: 22.2126899	total: 11.8ms	remaining: 1.17s
# 99:	learn: 14.5568068	total: 1.04s	remaining: 0us
# 0:	learn: 22.1090895	total: 24.8ms	remaining: 2.46s
# 99:	learn: 14.0722687	total: 985ms	remaining: 0us
# 99:	learn: 13.9868192	total: 831ms	remaining: 0us
# 0:	learn: 23.0808702	total: 9.6ms	remaining: 1.91s
# 0:	learn: 23.1296154	total: 20.3ms	remaining: 4.04s
# 99:	learn: 14.4934972	total: 1.52s	remaining: 0us
# 0:	learn: 23.0164285	total: 18.3ms	remaining: 3.65s
# 99:	learn: 13.9912737	total: 1.02s	remaining: 0us
# 0:	learn: 22.6769528	total: 24.2ms	remaining: 4.81s
# 100:	learn: 17.4201787	total: 1.02s	remaining: 1s
# 100:	learn: 17.4295709	total: 1.28s	remaining: 1.26s
# 100:	learn: 17.3565277	total: 1.48s	remaining: 1.45s
# 100:	learn: 14.5999074	total: 1.71s	remaining: 1.67s
# 199:	learn: 15.8207259	total: 2.63s	remaining: 0us
# 0:	learn: 22.7149670	total: 16.4ms	remaining: 3.26s
# 199:	learn: 15.8006463	total: 2.94s	remaining: 0us
# 0:	learn: 22.6062251	total: 9.88ms	remaining: 1.97s
# 199:	learn: 14.0459292	total: 2.69s	remaining: 0us
# 199:	learn: 15.7368363	total: 3.18s	remaining: 0us
# 0:	learn: 22.1858550	total: 20.6ms	remaining: 4.09s
# 0:	learn: 22.2105772	total: 15.4ms	remaining: 3.07s
# 100:	learn: 14.5088044	total: 1.05s	remaining: 1.03s
# 100:	learn: 14.5093512	total: 1.61s	remaining: 1.58s
# 199:	learn: 13.9634292	total: 2.13s	remaining: 0us
# 0:	learn: 22.1073052	total: 26.7ms	remaining: 5.32s
# 100:	learn: 13.9699601	total: 1.36s	remaining: 1.33s
# 100:	learn: 14.0491919	total: 1.8s	remaining: 1.76s
# 199:	learn: 13.4420679	total: 2.37s	remaining: 0us
# 199:	learn: 13.9864670	total: 3.06s	remaining: 0us
# 0:	learn: 23.0810185	total: 22.2ms	remaining: 4.42s
# 100:	learn: 13.9738057	total: 1.34s	remaining: 1.32s
# 0:	learn: 23.1297272	total: 31.4ms	remaining: 6.25s
# 199:	learn: 13.5231749	total: 3.5s	remaining: 0us
# 0:	learn: 23.0165230	total: 5.74ms	remaining: 1.14s
# 199:	learn: 13.4597819	total: 2.18s	remaining: 0us
# 0:	learn: 22.6776776	total: 9.9ms	remaining: 1.97s
# 100:	learn: 17.4311704	total: 1.66s	remaining: 1.63s
# 100:	learn: 17.4334409	total: 1.56s	remaining: 1.53s
# 100:	learn: 17.3522620	total: 1.3s	remaining: 1.28s
# 100:	learn: 14.6144840	total: 1.48s	remaining: 1.45s
# 199:	learn: 15.8219374	total: 3.16s	remaining: 0us
# 199:	learn: 15.7997645	total: 3.03s	remaining: 0us
# 0:	learn: 22.7155135	total: 19.7ms	remaining: 3.91s
# 0:	learn: 22.6066869	total: 26.9ms	remaining: 5.36s
# 199:	learn: 15.7519497	total: 2.67s	remaining: 0us
# 199:	learn: 14.0721685	total: 2.63s	remaining: 0us
# 0:	learn: 22.1872610	total: 21.6ms	remaining: 4.3s
# 0:	learn: 22.2116364	total: 19.2ms	remaining: 3.81s
# 100:	learn: 14.5209711	total: 1s	remaining: 984ms
# 100:	learn: 14.5191795	total: 1.42s	remaining: 1.39s
# 100:	learn: 14.0748544	total: 1.19s	remaining: 1.17s
# 100:	learn: 13.9798222	total: 1.27s	remaining: 1.24s
# 199:	learn: 13.9837325	total: 2.25s	remaining: 0us
# 199:	learn: 13.9875392	total: 2.3s	remaining: 0us
# 0:	learn: 22.1082001	total: 18.3ms	remaining: 3.63s
# 0:	learn: 23.0811615	total: 31.2ms	remaining: 6.21s
# 199:	learn: 13.4825194	total: 2.66s	remaining: 0us
# 199:	learn: 13.5794467	total: 2.8s	remaining: 0us
# 0:	learn: 23.1298384	total: 11.4ms	remaining: 2.27s
# 0:	learn: 23.0166169	total: 14.3ms	remaining: 2.84s
# 100:	learn: 13.9919055	total: 1.13s	remaining: 1.1s
# 100:	learn: 17.4361489	total: 1.77s	remaining: 1.73s
# 199:	learn: 13.4949105	total: 2.56s	remaining: 0us
# 100:	learn: 17.3513529	total: 1.68s	remaining: 1.65s
# 100:	learn: 17.4351724	total: 1.76s	remaining: 1.72s
# 0:	learn: 22.6783764	total: 12.7ms	remaining: 2.52s
# 199:	learn: 15.8346065	total: 3.47s	remaining: 0us
# 199:	learn: 15.8147406	total: 2.78s	remaining: 0us
# 0:	learn: 22.6071457	total: 9ms	remaining: 1.79s
# 0:	learn: 22.7160570	total: 23.7ms	remaining: 4.72s
# 199:	learn: 15.7476201	total: 2.99s	remaining: 0us
# 100:	learn: 14.6074302	total: 1.24s	remaining: 1.22s
# 0:	learn: 22.1886162	total: 16.1ms	remaining: 3.21s
# 100:	learn: 14.4865361	total: 917ms	remaining: 899ms
# 100:	learn: 14.5493445	total: 1.38s	remaining: 1.35s
# 100:	learn: 14.0664417	total: 1.34s	remaining: 1.32s
# 199:	learn: 14.0686280	total: 2.76s	remaining: 0us
# 0:	learn: 22.2126899	total: 23.1ms	remaining: 4.59s
# 199:	learn: 13.9898687	total: 2.04s	remaining: 0us
# 0:	learn: 22.1090895	total: 17.4ms	remaining: 3.45s
# 199:	learn: 13.9971152	total: 2.35s	remaining: 0us
# 0:	learn: 23.0694850	total: 28.3ms	remaining: 2.8s
# 199:	learn: 13.5943107	total: 3.14s	remaining: 0us
# 0:	learn: 23.1175608	total: 22.8ms	remaining: 2.25s
# 100:	learn: 13.9819206	total: 1.8s	remaining: 1.77s
# 100:	learn: 13.9855574	total: 1.95s	remaining: 1.91s
# 99:	learn: 16.9197708	total: 2.37s	remaining: 0us
# 0:	learn: 23.0100441	total: 20.9ms	remaining: 2.07s
# 199:	learn: 13.4810707	total: 3.48s	remaining: 0us
# 0:	learn: 22.6201152	total: 32.8ms	remaining: 3.24s
# 99:	learn: 16.8879427	total: 2.25s	remaining: 0us
# 199:	learn: 13.4945321	total: 3.6s	remaining: 0us
# 0:	learn: 22.5743489	total: 37.6ms	remaining: 3.72s
# 0:	learn: 22.6547581	total: 52.8ms	remaining: 5.22s
# 99:	learn: 16.8408004	total: 1.88s	remaining: 0us
# 99:	learn: 14.1354434	total: 1.45s	remaining: 0us
# 0:	learn: 22.0724828	total: 12.2ms	remaining: 1.21s
# 0:	learn: 22.0904026	total: 11.5ms	remaining: 1.13s
# 99:	learn: 14.0295478	total: 1.57s	remaining: 0us
# 0:	learn: 22.0437113	total: 24.7ms	remaining: 2.44s
# 99:	learn: 14.0546246	total: 2.08s	remaining: 0us
# 0:	learn: 23.0697220	total: 37.4ms	remaining: 3.71s
# 99:	learn: 13.5469857	total: 1.23s	remaining: 0us
# 99:	learn: 13.6176362	total: 1.3s	remaining: 0us
# 0:	learn: 23.1177735	total: 11.8ms	remaining: 1.17s
# 0:	learn: 23.0103313	total: 25.4ms	remaining: 2.51s
# 99:	learn: 13.5117758	total: 2.28s	remaining: 0us
# 0:	learn: 22.6212763	total: 23.2ms	remaining: 2.29s
# 99:	learn: 16.9086411	total: 1.85s	remaining: 0us
# 99:	learn: 16.9141262	total: 2.1s	remaining: 0us
# 0:	learn: 22.5757552	total: 9.49ms	remaining: 940ms
# 0:	learn: 22.6557998	total: 52.6ms	remaining: 5.21s
# 99:	learn: 16.8422740	total: 2.1s	remaining: 0us
# 0:	learn: 22.0747405	total: 21.3ms	remaining: 2.11s
# 99:	learn: 14.0614856	total: 1.78s	remaining: 0us
# 99:	learn: 13.6478259	total: 1.7s	remaining: 0us
# 0:	learn: 22.0924278	total: 27.3ms	remaining: 2.7s
# 99:	learn: 14.1277199	total: 2.54s	remaining: 0us
# 0:	learn: 22.0464458	total: 16.6ms	remaining: 1.64s
# 0:	learn: 23.0699508	total: 16.8ms	remaining: 1.67s
# 99:	learn: 14.0592577	total: 2.57s	remaining: 0us
# 0:	learn: 23.1179830	total: 13.3ms	remaining: 1.31s
# 99:	learn: 13.5697753	total: 1.47s	remaining: 0us
# 0:	learn: 23.0106024	total: 14.6ms	remaining: 1.44s
# 99:	learn: 13.5357503	total: 1.65s	remaining: 0us
# 0:	learn: 22.6223972	total: 32.3ms	remaining: 3.19s
# 99:	learn: 16.9277492	total: 1.75s	remaining: 0us
# 0:	learn: 22.6568262	total: 22.3ms	remaining: 2.21s
# 99:	learn: 16.9138925	total: 2.04s	remaining: 0us
# 99:	learn: 16.8642819	total: 1.25s	remaining: 0us
# 0:	learn: 22.5770836	total: 40.4ms	remaining: 4s
# 0:	learn: 22.0769200	total: 34ms	remaining: 3.36s
# 99:	learn: 14.0723002	total: 1.39s	remaining: 0us
# 99:	learn: 14.1457813	total: 1.86s	remaining: 0us
# 0:	learn: 22.0944238	total: 37ms	remaining: 3.66s
# 0:	learn: 22.0490299	total: 37.1ms	remaining: 3.68s
# 99:	learn: 13.6691648	total: 1.62s	remaining: 0us
# 0:	learn: 23.0694850	total: 13.5ms	remaining: 2.68s
# 99:	learn: 14.0828844	total: 2.03s	remaining: 0us
# 0:	learn: 23.1175608	total: 26.3ms	remaining: 5.24s
# 100:	learn: 16.8878233	total: 1.38s	remaining: 1.35s
# 99:	learn: 13.5964320	total: 2.37s	remaining: 0us
# 99:	learn: 13.5759944	total: 2.29s	remaining: 0us
# 0:	learn: 23.0100441	total: 37.9ms	remaining: 7.55s
# 0:	learn: 22.6201152	total: 9.56ms	remaining: 1.9s
# 100:	learn: 16.8564046	total: 1.84s	remaining: 1.8s
# 199:	learn: 15.2134726	total: 3.45s	remaining: 0us
# 0:	learn: 22.6547581	total: 26.4ms	remaining: 5.25s
# 199:	learn: 15.1524765	total: 3.73s	remaining: 0us
# 100:	learn: 14.1268816	total: 2.48s	remaining: 2.43s
# 100:	learn: 16.8115528	total: 2.74s	remaining: 2.68s
# 0:	learn: 22.5743489	total: 22.9ms	remaining: 4.57s
# 100:	learn: 14.0458600	total: 1.68s	remaining: 1.65s
# 199:	learn: 15.1558707	total: 4.62s	remaining: 0us
# 199:	learn: 13.5994191	total: 4.47s	remaining: 0us
# 100:	learn: 14.0239898	total: 1.86s	remaining: 1.83s
# 0:	learn: 22.0724828	total: 16.6ms	remaining: 3.29s
# 0:	learn: 22.0904026	total: 33.5ms	remaining: 6.67s
# 199:	learn: 13.4989782	total: 3.3s	remaining: 0us
# 0:	learn: 22.0437113	total: 7.24ms	remaining: 1.44s
# 199:	learn: 13.4886483	total: 3.29s	remaining: 0us
# 0:	learn: 23.0697220	total: 28.2ms	remaining: 5.61s
# 100:	learn: 13.6101612	total: 1.76s	remaining: 1.73s
# 100:	learn: 13.5370468	total: 1.8s	remaining: 1.77s
# 100:	learn: 13.4998325	total: 1.59s	remaining: 1.56s
# 199:	learn: 12.8617410	total: 3s	remaining: 0us
# 0:	learn: 23.1177735	total: 25ms	remaining: 4.97s
# 100:	learn: 16.8830064	total: 2.01s	remaining: 1.97s
# 199:	learn: 12.9482875	total: 3.62s	remaining: 0us
# 0:	learn: 23.0103313	total: 35.5ms	remaining: 7.06s
# 199:	learn: 12.8346487	total: 3.92s	remaining: 0us
# 0:	learn: 22.6212763	total: 29.3ms	remaining: 5.83s
# 100:	learn: 16.8769620	total: 2s	remaining: 1.96s
# 199:	learn: 15.2199413	total: 4s	remaining: 0us
# 0:	learn: 22.6557998	total: 29.1ms	remaining: 5.79s
# 100:	learn: 16.8134839	total: 2.47s	remaining: 2.42s
# 199:	learn: 15.1801429	total: 3.9s	remaining: 0us
# 0:	learn: 22.5757552	total: 31.5ms	remaining: 6.26s
# 100:	learn: 14.1219782	total: 2.83s	remaining: 2.78s
# 100:	learn: 14.0506280	total: 2.24s	remaining: 2.2s
# 199:	learn: 15.1567834	total: 4.69s	remaining: 0us
# 0:	learn: 22.0747405	total: 36.4ms	remaining: 7.24s
# 100:	learn: 14.0529395	total: 2.43s	remaining: 2.38s
# 199:	learn: 13.5299060	total: 4.24s	remaining: 0us
# 199:	learn: 13.6230289	total: 5.24s	remaining: 0us
# 0:	learn: 22.0924278	total: 7.33ms	remaining: 1.46s
# 0:	learn: 22.0464458	total: 13.7ms	remaining: 2.72s
# 100:	learn: 13.6418935	total: 2.18s	remaining: 2.13s
# 199:	learn: 13.5360898	total: 4.19s	remaining: 0us
# 0:	learn: 23.0699508	total: 37.9ms	remaining: 7.54s
# 100:	learn: 13.5609711	total: 2.05s	remaining: 2.01s
# 199:	learn: 13.0282721	total: 3.75s	remaining: 0us
# 0:	learn: 23.1179830	total: 15.6ms	remaining: 3.11s
# 100:	learn: 13.5285130	total: 2.35s	remaining: 2.31s
# 100:	learn: 16.8964921	total: 2s	remaining: 1.96s
# 100:	learn: 16.8823376	total: 1.87s	remaining: 1.83s
# 199:	learn: 12.9494817	total: 4.58s	remaining: 0us
# 0:	learn: 23.0106024	total: 52.1ms	remaining: 10.4s
# 199:	learn: 12.9091298	total: 4.87s	remaining: 0us
# 0:	learn: 22.6223972	total: 32.3ms	remaining: 6.43s
# 199:	learn: 15.2196175	total: 4.05s	remaining: 0us
# 0:	learn: 22.6568262	total: 7.48ms	remaining: 1.49s
# 199:	learn: 15.1842337	total: 3.78s	remaining: 0us
# 0:	learn: 22.5770836	total: 24.5ms	remaining: 4.87s
# 100:	learn: 16.8350603	total: 2.04s	remaining: 2s
# 100:	learn: 14.1404864	total: 2.07s	remaining: 2.03s
# 100:	learn: 14.0635461	total: 2.1s	remaining: 2.06s
# 100:	learn: 14.0762332	total: 1.75s	remaining: 1.71s
# 199:	learn: 13.6521283	total: 3.58s	remaining: 0us
# 199:	learn: 15.1661774	total: 4.06s	remaining: 0us
# 0:	learn: 22.0769200	total: 16.1ms	remaining: 3.19s
# 0:	learn: 22.0944238	total: 39ms	remaining: 7.75s
# 199:	learn: 13.5445531	total: 4.17s	remaining: 0us
# 199:	learn: 13.5759998	total: 3.78s	remaining: 0us
# 0:	learn: 22.0490299	total: 36.2ms	remaining: 7.21s
# 0:	learn: 23.0651087	total: 46.8ms	remaining: 4.63s
# 100:	learn: 13.6656643	total: 1.63s	remaining: 1.6s
# 100:	learn: 13.5889618	total: 1.95s	remaining: 1.91s
# 100:	learn: 13.5694253	total: 2.2s	remaining: 2.15s
# 199:	learn: 13.0832029	total: 3.99s	remaining: 0us
# 0:	learn: 23.1126709	total: 25.6ms	remaining: 2.53s
# 199:	learn: 12.9858788	total: 4.11s	remaining: 0us
# 0:	learn: 23.0026819	total: 38.6ms	remaining: 3.82s
# 99:	learn: 16.5328936	total: 3.17s	remaining: 0us
# 0:	learn: 22.5982194	total: 38.3ms	remaining: 3.79s
# 199:	learn: 12.9788925	total: 4.06s	remaining: 0us
# 0:	learn: 22.6302765	total: 50.2ms	remaining: 4.97s
# 99:	learn: 16.5215857	total: 3.11s	remaining: 0us
# 0:	learn: 22.5375419	total: 49.5ms	remaining: 4.9s
# 99:	learn: 16.4562441	total: 3.42s	remaining: 0us
# 0:	learn: 22.0286814	total: 42.2ms	remaining: 4.18s
# 99:	learn: 13.7422145	total: 3.34s	remaining: 0us
# 0:	learn: 22.0413870	total: 63.5ms	remaining: 6.29s
# 99:	learn: 13.6511515	total: 3.64s	remaining: 0us
# 0:	learn: 21.9701550	total: 62.1ms	remaining: 6.14s
# 99:	learn: 13.6669743	total: 3.26s	remaining: 0us
# 0:	learn: 23.0657009	total: 40.3ms	remaining: 3.99s
# 99:	learn: 13.1620482	total: 3.38s	remaining: 0us
# 0:	learn: 23.1133040	total: 61ms	remaining: 6.04s
# 99:	learn: 13.0426402	total: 3.37s	remaining: 0us
# 0:	learn: 23.0032490	total: 64.7ms	remaining: 6.4s
# 99:	learn: 13.0680531	total: 3.67s	remaining: 0us
# 0:	learn: 22.6011252	total: 67.1ms	remaining: 6.64s
# 99:	learn: 16.5607748	total: 3.3s	remaining: 0us
# 0:	learn: 22.6333842	total: 42.7ms	remaining: 4.23s
# 99:	learn: 16.5488798	total: 3.05s	remaining: 0us
# 0:	learn: 22.5403247	total: 51.3ms	remaining: 5.08s
# 99:	learn: 16.4860768	total: 3.96s	remaining: 0us
# 0:	learn: 22.0343451	total: 45.3ms	remaining: 4.48s
# 99:	learn: 13.7912162	total: 4s	remaining: 0us
# 0:	learn: 22.0474472	total: 54.2ms	remaining: 5.37s
# 99:	learn: 13.7131232	total: 3.31s	remaining: 0us
# 99:	learn: 13.7114018	total: 3.91s	remaining: 0us
# 0:	learn: 21.9755789	total: 25ms	remaining: 2.47s
# 0:	learn: 23.0662494	total: 30.4ms	remaining: 3.01s
# 99:	learn: 13.2475135	total: 3.8s	remaining: 0us
# 0:	learn: 23.1138957	total: 79.1ms	remaining: 7.83s
# 99:	learn: 13.1303224	total: 4.1s	remaining: 0us
# 0:	learn: 23.0037706	total: 60.7ms	remaining: 6.01s
# 99:	learn: 13.1695507	total: 3.6s	remaining: 0us
# 0:	learn: 22.6038177	total: 53.1ms	remaining: 5.25s
# 99:	learn: 16.5810198	total: 4.46s	remaining: 0us
# 0:	learn: 22.6362902	total: 57.5ms	remaining: 5.69s
# 99:	learn: 16.5643578	total: 3.39s	remaining: 0us
# 0:	learn: 22.5428859	total: 37.1ms	remaining: 3.68s
# 99:	learn: 16.5072132	total: 3.92s	remaining: 0us
# 0:	learn: 22.0395953	total: 65.4ms	remaining: 6.47s
# 99:	learn: 13.8109356	total: 3.98s	remaining: 0us
# 0:	learn: 22.0531165	total: 48.5ms	remaining: 4.8s
# 99:	learn: 13.7151415	total: 3.42s	remaining: 0us
# 0:	learn: 21.9805767	total: 89.1ms	remaining: 8.82s
# 99:	learn: 13.7424178	total: 2.94s	remaining: 0us
# 0:	learn: 23.0651087	total: 33.3ms	remaining: 6.62s
# 99:	learn: 13.3153808	total: 3.16s	remaining: 0us
# 0:	learn: 23.1126709	total: 55.6ms	remaining: 11.1s
# 99:	learn: 13.1873611	total: 3.28s	remaining: 0us
# 0:	learn: 23.0026819	total: 47.3ms	remaining: 9.42s
# 99:	learn: 13.2130873	total: 3.45s	remaining: 0us
# 100:	learn: 16.5032170	total: 3.33s	remaining: 3.26s
# 0:	learn: 22.5982194	total: 64.3ms	remaining: 12.8s
# 100:	learn: 16.4899461	total: 3.43s	remaining: 3.37s
# 199:	learn: 14.8094588	total: 6.87s	remaining: 0us
# 100:	learn: 13.7351852	total: 3.64s	remaining: 3.57s
# 100:	learn: 16.4263708	total: 4.05s	remaining: 3.97s
# 0:	learn: 22.6302765	total: 32ms	remaining: 6.37s
# 199:	learn: 14.7780817	total: 7.25s	remaining: 0us
# 0:	learn: 22.5375419	total: 42.9ms	remaining: 8.54s
# 199:	learn: 13.1205908	total: 7.07s	remaining: 0us
# 0:	learn: 22.0286814	total: 55.5ms	remaining: 11.1s
# 100:	learn: 13.6445741	total: 3.67s	remaining: 3.6s
# 199:	learn: 14.7528021	total: 7.8s	remaining: 0us
# 0:	learn: 22.0413870	total: 35ms	remaining: 6.96s
# 100:	learn: 13.6585446	total: 3.64s	remaining: 3.57s
# 199:	learn: 13.0248924	total: 6.75s	remaining: 0us
# 0:	learn: 21.9701550	total: 24.5ms	remaining: 4.88s
# 100:	learn: 13.1482053	total: 3.57s	remaining: 3.5s
# 100:	learn: 13.0339413	total: 3.58s	remaining: 3.51s
# 199:	learn: 13.0275430	total: 7.25s	remaining: 0us
# 100:	learn: 13.0563081	total: 3.23s	remaining: 3.17s
# 0:	learn: 23.0657009	total: 36.7ms	remaining: 7.3s
# 199:	learn: 12.1003045	total: 6.64s	remaining: 0us
# 199:	learn: 12.2435003	total: 7.2s	remaining: 0us
# 0:	learn: 23.1133040	total: 34.9ms	remaining: 6.95s
# 0:	learn: 23.0032490	total: 27ms	remaining: 5.38s
# 100:	learn: 16.5310517	total: 3.86s	remaining: 3.78s
# 100:	learn: 16.5179482	total: 3.31s	remaining: 3.25s
# 199:	learn: 12.1241643	total: 7.35s	remaining: 0us
# 0:	learn: 22.6011252	total: 52.7ms	remaining: 10.5s
# 100:	learn: 16.4546419	total: 3.92s	remaining: 3.85s
# 199:	learn: 14.8311200	total: 7.7s	remaining: 0us
# 0:	learn: 22.6333842	total: 71.7ms	remaining: 14.3s
# 100:	learn: 13.7848345	total: 3.73s	remaining: 3.65s
# 199:	learn: 14.7959132	total: 7.42s	remaining: 0us
# 0:	learn: 22.5403247	total: 29.7ms	remaining: 5.92s
# 199:	learn: 14.7735318	total: 8.37s	remaining: 0us
# 0:	learn: 22.0343451	total: 17.5ms	remaining: 3.48s
# 199:	learn: 13.2294531	total: 7.51s	remaining: 0us
# 100:	learn: 13.7048315	total: 3.58s	remaining: 3.51s
# 100:	learn: 13.7048409	total: 4.1s	remaining: 4.02s
# 0:	learn: 22.0474472	total: 40.3ms	remaining: 8.01s
# 100:	learn: 13.2348941	total: 3.34s	remaining: 3.28s
# 199:	learn: 13.1188221	total: 7.16s	remaining: 0us
# 100:	learn: 13.1191081	total: 3s	remaining: 2.94s
# 199:	learn: 13.1042531	total: 6.72s	remaining: 0us
# 0:	learn: 21.9755789	total: 35.9ms	remaining: 7.15s
# 0:	learn: 23.0662494	total: 50.4ms	remaining: 10s
# 199:	learn: 12.4288589	total: 6.39s	remaining: 0us
# 0:	learn: 23.1138957	total: 33ms	remaining: 6.56s
# 199:	learn: 12.3021300	total: 6.57s	remaining: 0us
# 100:	learn: 16.5522265	total: 3.38s	remaining: 3.32s
# 0:	learn: 23.0037706	total: 37.1ms	remaining: 7.38s
# 100:	learn: 13.1596083	total: 3.78s	remaining: 3.7s
# 100:	learn: 16.5343892	total: 4.18s	remaining: 4.1s
# 199:	learn: 14.8526048	total: 6.33s	remaining: 0us
# 0:	learn: 22.6038177	total: 58.5ms	remaining: 11.6s
# 100:	learn: 16.4768202	total: 3.5s	remaining: 3.43s
# 199:	learn: 12.3194774	total: 7.17s	remaining: 0us
# 0:	learn: 22.6362902	total: 53.3ms	remaining: 10.6s
# 199:	learn: 14.8137958	total: 7.43s	remaining: 0us
# 0:	learn: 22.5428859	total: 68.8ms	remaining: 13.7s
# 100:	learn: 13.8044206	total: 2.79s	remaining: 2.73s
# 199:	learn: 14.7902194	total: 6.85s	remaining: 0us
# 0:	learn: 22.0395953	total: 34.7ms	remaining: 6.9s
# 100:	learn: 13.7079616	total: 3.61s	remaining: 3.54s
# 100:	learn: 13.7354220	total: 3.5s	remaining: 3.43s
# 199:	learn: 13.2719965	total: 6.02s	remaining: 0us
# 0:	learn: 22.0531165	total: 50.2ms	remaining: 10s
# 199:	learn: 13.1549127	total: 6.56s	remaining: 0us
# 0:	learn: 21.9805767	total: 42.4ms	remaining: 8.44s
# 100:	learn: 13.3078309	total: 4.03s	remaining: 3.95s
# 199:	learn: 13.1671821	total: 7.19s	remaining: 0us
# 100:	learn: 13.1745812	total: 3.52s	remaining: 3.45s
# 100:	learn: 13.2025493	total: 2.5s	remaining: 2.45s
# 199:	learn: 12.5687992	total: 7.29s	remaining: 0us
# 199:	learn: 12.3820904	total: 5.4s	remaining: 0us
# 199:	learn: 12.4242101	total: 4.25s	remaining: 0us
# 0:	learn: 22.0184948	total: 12.7ms	remaining: 2.53s
# 100:	learn: 13.1670761	total: 796ms	remaining: 780ms
# 199:	learn: 12.3546152	total: 1.53s	remaining: 0us
# GridSearchCV(cv=KFold(n_splits=3, random_state=42, shuffle=True),
#              estimator=<catboost.core.CatBoostRegressor object at 0x7b63ac23e290>,
#              n_jobs=-1,
#              param_grid={'depth': [4, 6, 8], 'iterations': [100, 200],
#                          'l2_leaf_reg': [1, 3, 5],
#                          'learning_rate': [0.01, 0.05, 0.1]},
#              scoring='neg_mean_squared_error')

# %%
best_params = grid_search.best_params_
best_rmse = np.sqrt(-grid_search.best_score_)
print("\nGrid Search Results:")
print(f"Best Parameters: {best_params}")
print(f"Best RMSE (CV): {best_rmse:.2f}")
# Out:
# Grid Search Results:
# Best Parameters: {'depth': 8, 'iterations': 200, 'l2_leaf_reg': 1, 'learning_rate': 0.1}
# Best RMSE (CV): 13.37

# %%
best_model = CatBoostRegressor(**best_params, random_seed=42, verbose=0)
rmse_scores = []
r2_scores = []
for train_idx, test_idx in cv.split(X):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    # Train model
    best_model.fit(X_train, y_train)
    
    # Predict and evaluate
    y_pred = best_model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    rmse_scores.append(rmse)
    r2_scores.append(r2)
    
print("\nCross-Validation Results (Best Model):")
print(f"RMSE Scores: {rmse_scores}")
print(f"Mean RMSE: {np.mean(rmse_scores):.2f} ± {np.std(rmse_scores):.2f}")
print(f"R² Scores: {r2_scores}")
print(f"Mean R²: {np.mean(r2_scores):.2f} ± {np.std(r2_scores):.2f}")
# Out:
# Cross-Validation Results (Best Model):
# RMSE Scores: [13.247714472899894, 13.444947241776418, 13.424481469849672]
# Mean RMSE: 13.37 ± 0.09
# R² Scores: [0.6731491441592196, 0.6603019667898364, 0.667961632850183]
# Mean R²: 0.67 ± 0.01

# %%
best_model.fit(X, y)

# Predict and evaluate
y_pred_final = best_model.predict(X)
final_rmse = np.sqrt(mean_squared_error(y, y_pred_final))
final_r2 = r2_score(y, y_pred_final)
print("\nFinal Model (Trained on Full Data):")
print(f"RMSE: {final_rmse:.2f}")
print(f"R²: {final_r2:.2f}")
# Out:
# Final Model (Trained on Full Data):
# RMSE: 12.35
# R²: 0.72

# %%
plt.figure(figsize=(15, 6))
feature_importance = pd.Series(best_model.feature_importances_, index=features)
feature_importance.sort_values(ascending=False).plot(kind='bar')
plt.title('Feature Importance')
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.scatter(y, y_pred_final, alpha=0.6,color="navy")
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--', lw=2)
plt.title('Actual vs. Predicted Confidence')
plt.xlabel('Actual Confidence')
plt.ylabel('Predicted Confidence')
plt.show()

# %%
residuals = y - y_pred_final

# Subplots: Residual Plot, Prediction Error Distribution
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
fig.suptitle('Model Performance Visualizations')

# Residual Plot
axes[0].scatter(y_pred_final, residuals, alpha=0.6, color="purple")
axes[0].axhline(0, color='red', linestyle='--', lw=2)
axes[0].set_title('Residual Plot')
axes[0].set_xlabel('Predicted Confidence')
axes[0].set_ylabel('Residuals (Actual - Predicted)')

# Prediction Error Distribution
sns.histplot(residuals, bins=5, kde=True, ax=axes[1], color="teal")
axes[1].set_title('Distribution of Prediction Errors')
axes[1].set_xlabel('Residuals')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from sklearn.inspection import permutation_importance
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
fig.suptitle('Feature Importance')

# CatBoost Feature Importance
feature_importance = pd.Series(best_model.feature_importances_, index=features)
feature_importance.sort_values(ascending=False).plot(kind='bar', ax=axes[0], color='green')
axes[0].set_title('CatBoost Feature Importance')
axes[0].set_xlabel('Features')
axes[0].set_ylabel('Importance')

# Permutation Importance
perm_importance = permutation_importance(best_model, X, y, n_repeats=10, random_state=42)
perm_importance_mean = pd.Series(perm_importance.importances_mean, index=features)
perm_importance_mean.sort_values(ascending=False).plot(kind='bar', ax=axes[1], color='orange')
axes[1].set_title('Permutation Importance')
axes[1].set_xlabel('Features')
axes[1].set_ylabel('Importance')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
fig.suptitle('Predicted Confidence vs. Features')
axes = axes.flatten()

for i, feature in enumerate(features):
    axes[i].scatter(df[feature], y_pred_final, alpha=0.6, color="blue")
    axes[i].set_title(f'vs. {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Predicted Confidence')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
fig.suptitle('Residuals vs. Features')
axes = axes.flatten()

for i, feature in enumerate(features):
    axes[i].scatter(df[feature], residuals, alpha=0.6, color="red")
    axes[i].axhline(0, color='black', linestyle='--', lw=1)
    axes[i].set_title(f'vs. {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Residuals')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6), subplot_kw={'projection': ccrs.PlateCarree()})
fig.suptitle('Spatial Distribution of Confidence')

# Actual Confidence
axes[0].add_feature(cfeature.LAND)
axes[0].add_feature(cfeature.OCEAN)
axes[0].add_feature(cfeature.COASTLINE)
scatter_actual = axes[0].scatter(df['longitude'], df['latitude'], c=y, s=100, cmap='viridis', transform=ccrs.PlateCarree())
axes[0].set_title('Actual Confidence')
axes[0].set_extent([130, 145, -15, -10], crs=ccrs.PlateCarree())
fig.colorbar(scatter_actual, ax=axes[0], label='Actual Confidence')

# Predicted Confidence
axes[1].add_feature(cfeature.LAND)
axes[1].add_feature(cfeature.OCEAN)
axes[1].add_feature(cfeature.COASTLINE)
scatter_pred = axes[1].scatter(df['longitude'], df['latitude'], c=y_pred_final, s=100, cmap='viridis', transform=ccrs.PlateCarree())
axes[1].set_title('Predicted Confidence')
axes[1].set_extent([130, 145, -15, -10], crs=ccrs.PlateCarree())
fig.colorbar(scatter_pred, ax=axes[1], label='Predicted Confidence')

plt.tight_layout()
plt.show()
