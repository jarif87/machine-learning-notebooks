# %%
import pyttsx3 ##for the ai to speak,## text to speech library
import datetime
import speech_recognition as sr ##for getting input voices   ## speech to text library
import wikipedia ##for surfing wikipedia
import os  ##for opening local files
import webbrowser ## for surfing the internet

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
if voices:
    engine.setProperty('voice', voices[0].id)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def greet():
    hour = int(datetime.datetime.now().hour)
    if hour >= 0 and hour < 12:
        speak("It is a fine morning sir!")
    elif hour >= 12 and hour < 18:
        speak("Hope you had your brunch, Good Afternoon Sir!")
    else:
        speak("The wind is lovely, Good Evening sir!")
    speak("Hello How are you? I am your personal AI Assistant Dave! How can I be of service")

# %%
def command():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.adjust_for_ambient_noise(source, duration=1)  # Adjust for ambient noise
        r.pause_threshold = 1.2
        audio = r.listen(source)
    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f"You said: {query}\n")
    except:
        print("I could not get you, please speak again")
        speak("I could not get you, please speak again")
        return "None"
    return query

# %%
if __name__ == "__main__":
    greet()
    while True:
        query = command().lower()

        if 'stop' in query or 'quit' in query or 'exit' in query:
            speak("Goodbye, sir!")
            break

        if 'wikipedia' in query:
            speak('Searching Wikipedia...')
            query = query.replace("wikipedia", "")
            results = wikipedia.summary(f'{query}', sentences=2)
            speak("According to Wikipedia")
            print(results)
            speak(results)

        elif 'open instagram' in query:
            webbrowser.open("instagram.com")

        elif 'open youtube' in query:
            webbrowser.open("youtube.com")
            speak("YouTube is open. What would you like to watch or search for?")
            follow_up_query = command().lower()
            if follow_up_query != "None":
                speak(f"Searching YouTube for {follow_up_query}")
                webbrowser.open(f"https://www.youtube.com/results?search_query={follow_up_query.replace(' ', '+')}")

        elif 'open google' in query:
            webbrowser.open("google.com")

        elif 'open kaggle' in query:
            webbrowser.open("kaggle.com")

        elif 'the weather' in query:
            webbrowser.open("weather.com")

        elif 'the score' in query:
            webbrowser.open("cricbuzz.com")

        elif 'play music' in query:
            webbrowser.open("https://open.spotify.com")
            speak("Spotify is open. What song or artist would you like to play?")
            follow_up_query = command().lower()
            if follow_up_query != "None":
                speak(f"Searching Spotify for {follow_up_query}")
                webbrowser.open(f"https://open.spotify.com/search/{follow_up_query.replace(' ', '%20')}")

        elif 'the time' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"Sir, the time is {strTime}")

        elif 'open anaconda' in query:
            webbrowser.open("https://www.anaconda.com")

        elif 'discord' in query:
            webbrowser.open("https://discord.com")
# Out:
# Listening...
# Recognizing...
# You said: play music
#
# Listening...
# Recognizing...
# You said: open YouTube
#
# Listening...
# Recognizing...
# I could not get you, please speak again
# Listening...
# Recognizing...
# You said: Gopal Bhar
#
# Listening...
# Recognizing...
# I could not get you, please speak again
# Listening...
# Recognizing...
# I could not get you, please speak again
# Listening...
# Recognizing...
# I could not get you, please speak again
# Listening...
# Recognizing...
# You said: play any TV series
#
# Listening...
# Recognizing...
# You said: from YouTube
#
# Listening...
# Recognizing...
# You said: open YouTube
#
# Listening...
# Recognizing...
# You said: play TV series
#
# Listening...
# Recognizing...
# You said: Sheela TV series 32
#
# Listening...
# Recognizing...
# You said: thriller
#
# Listening...
# Recognizing...
# You said: write 300000 TV series
#
# Listening...
# Recognizing...
# I could not get you, please speak again
# Listening...
# ...
